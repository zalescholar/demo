# %% [markdown]
# # This is a title
# 1. this is interesting
# 2. this is even more insteresting

# %%
import numpy as np
import seaborn as sns

# %%
x = np.array([1,2,3,4,5,4,6,7,1,2,3,5,8])

# %%
sns.distplot(x)
